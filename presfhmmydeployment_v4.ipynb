# %% [markdown]
# <a href="https://colab.research.google.com/github/Ckontogi24/CPS_Workshop/blob/main/presfhmmydeployment_v4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup Environment

# %%
# %env UID=683f1c07c03ba2f496486f14
# Out:
# env: UID=6530f9263773c5f7858b6b33

# %%
# !apt update && apt upgrade && apt-get install -y software-properties-common redis-server
# !service redis-server start

# !pip install https://github.com/robotics-4-all/commlib-py/archive/devel.zip -Uq
# !pip install https://github.com/robotics-4-all/goalee/archive/devel.zip -Uq

# !git clone https://github.com/robotics-4-all/streamsim.git
# !cd streamsim/ && git checkout tags/v0.7.0
# !cd streamsim/ && pip3 install -r requirements.txt
# !cd streamsim && pip3 install .

# !bash -c '[ ! -z appmaker-executor ] && git clone https://github.com/robotics-4-all/appmaker-executor.git'
# !bash -c '[ ! -z goal-dsl ] && git clone https://github.com/robotics-4-all/goal-dsl.git && cd goal-dsl && git checkout hackathon_2025 && pip install .'
# !bash -c '[ ! -z goaldsl-executor ] && git clone https://github.com/robotics-4-all/goaldsl-executor.git && cd goaldsl-executor && git checkout hackathon_2025 && pip install -r requirements.txt'

# %% [markdown]
# # Start Executors

# %%
# Setup and Deploy required Executors
# %env USE_REDIS=1

# %env BROKER_TYPE=MQTT
# %env BROKER_HOST=locsys.issel.ee.auth.gr
# %env BROKER_PORT=8883
# %env BROKER_SSL=True
# %env BROKER_USERNAME=sensors
# %env BROKER_PASSWORD=issel.sensors
# %env HEARTBEATS=False
# %env DEBUG=False
# %env WAIT_FOR_EXECUTION_TERMINATION=False

# %env GOALDSL_ZERO_LOGS=0
# %env GOALDSL_LOG_LEVEL=CRITICAL
# %env STREAMSIM_ZERO_LOGS=0
# %env STREAMSIM_LOG_LEVEL=CRITICAL
# %env APPMAKER_ZERO_LOGS=1
# %env APPMAKER_LOG_LEVEL=CRITICAL


# Setup and Deploy StreamSim
# !bash -c '[ -f streamsim.pid ] && pid=$(cat streamsim.pid) && kill $pid'
# !nohup python3 streamsim/stream_simulator/bin/main.py ${UID} > streamsim.log 2>&1 & echo $! > streamsim.pid

# Setup and Deploy AppMaker-Executor
# !bash -c '[ -f appexecutor.pid ] && pid=$(cat appexecutor.pid) && kill $pid'
# !nohup python appmaker-executor/appmakerexecutor/src/appmakerexecutor/appmaker.py ${UID} > appexecutor.log 2>&1 & echo $! > appexecutor.pid

# Setup and Deploy GoalDSL-Executor
# !bash -c '[ -f goalexecutor.pid ] && pid=$(cat goalexecutor.pid) && kill $pid'
# !nohup python goaldsl-executor/executor.py > goalexecutor.log 2>&1 & echo $! > goalexecutor.pid

print("READY !!!")
# Check for errors
# !tail -f goalexecutor.log appexecutor.log streamsim.log # | grep -E "error|warning|Error|Warning|ERROR|WARNING|Reconnecting in"
# Out:
# env: USE_REDIS=1
# env: BROKER_TYPE=MQTT
# env: BROKER_HOST=locsys.issel.ee.auth.gr
# env: BROKER_PORT=8883
# env: BROKER_SSL=True
# env: BROKER_USERNAME=sensors
# env: BROKER_PASSWORD=issel.sensors
# env: HEARTBEATS=False
# env: DEBUG=False
# env: WAIT_FOR_EXECUTION_TERMINATION=False
# env: GOALDSL_ZERO_LOGS=0
# env: GOALDSL_LOG_LEVEL=CRITICAL
# env: STREAMSIM_ZERO_LOGS=0
# env: STREAMSIM_LOG_LEVEL=CRITICAL
# env: APPMAKER_ZERO_LOGS=1
# env: APPMAKER_LOG_LEVEL=CRITICAL
# bash: line 1: kill: (2509) - No such process
# bash: line 1: kill: (2512) - No such process
# bash: line 1: kill: (2516) - No such process
# READY !!!
# ==> goalexecutor.log <==
#
# ==> appexecutor.log <==
#
# ==> streamsim.log <==
# CRITICAL : stream_simulator.simulator : Simulator UID is: 683f1c07c03ba2f496486f14
#
# ==> appexecutor.log <==
# Connected to broker
#
# ==> streamsim.log <==
# CRITICAL : stream_simulator.simulator : Stopping world
# CRITICAL : stream_simulator.world : World: Cleaning actors
# Exception in thread Thread-13:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 88, in read_from_socket
#     bufflen = self._sock.recv_into(self._buffer)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 591, in can_read
# Exception in thread Thread-36:
# Traceback (most recent call last):
# Exception in thread Thread-18:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 591, in can_read
# Exception in thread Thread-11 (run_forever):
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 62, in call_with_retry
#     return do()
#            ^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 903, in <lambda>
# Exception in thread Thread-24:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 591, in can_read
#     return self._parser.can_read(timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 79, in can_read
#     return self.read_from_socket(timeout=timeout, raise_on_timeout=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 110, in read_from_socket
# Exception in thread Thread-43:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 591, in can_read
#     sock.settimeout(self._socket_timeout)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 62, in call_with_retry
#     return self._parser.can_read(timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 79, in can_read
# Exception in thread Thread-16 (run_forever):
#     return self._parser.can_read(timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 79, in can_read
#     return self.read_from_socket(timeout=timeout, raise_on_timeout=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 110, in read_from_socket
#     sock.settimeout(self._socket_timeout)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#     lambda: command(*args, **kwargs),
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 577, in send_command
#     self.send_packed_command(
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 547, in send_packed_command
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 88, in read_from_socket
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 62, in call_with_retry
#     return do()
#     bufflen = self._sock.recv_into(self._buffer)
#     self.connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 390, in connect
#     self.run()
# Exception in thread Thread-19:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 591, in can_read
#     self.on_connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 492, in on_connect
#     self.read_response()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 613, in read_response
#     response = self._parser.read_response(disable_decoding=disable_decoding)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 128, in read_response
#     self.read_from_socket()
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 90, in read_from_socket
#     raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
# redis.exceptions.ConnectionError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/commlib/transports/redis.py", line 812, in run_forever
#     return do()
#            ^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 903, in <lambda>
#     return self.read_from_socket(timeout=timeout, raise_on_timeout=False)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     return self._parser.can_read(timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 79, in can_read
# OSError: [Errno 9] Bad file descriptor
#
#     return self.read_from_socket(timeout=timeout, raise_on_timeout=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 110, in read_from_socket
#     self.run()
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 591, in can_read
#     sock.settimeout(self._socket_timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 110, in read_from_socket
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 62, in call_with_retry
#     return do()
#            ^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 903, in <lambda>
#     lambda: command(*args, **kwargs),
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 920, in try_read
#     if not conn.can_read(timeout=timeout):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 594, in can_read
#     raise ConnectionError(f"Error while reading from {host_error}: {e.args}")
# redis.exceptions.ConnectionError: Error while reading from localhost:6379: (9, 'Bad file descriptor')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1253, in run
#     lambda: command(*args, **kwargs),
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 920, in try_read
#     if not conn.can_read(timeout=timeout):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 594, in can_read
#     raise ConnectionError(f"Error while reading from {host_error}: {e.args}")
#            ^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 903, in <lambda>
#     lambda: command(*args, **kwargs),
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 920, in try_read
#     if not conn.can_read(timeout=timeout):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 594, in can_read
#     return self._parser.can_read(timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 79, in can_read
#     return self.read_from_socket(timeout=timeout, raise_on_timeout=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 110, in read_from_socket
#     sock.settimeout(self._socket_timeout)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 62, in call_with_retry
#     return do()
#            ^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 903, in <lambda>
#     sock.settimeout(self._socket_timeout)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 62, in call_with_retry
#     self._transport._rsub.ping()
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1127, in ping
# redis.exceptions.ConnectionError: Error while reading from localhost:6379: (9, 'Bad file descriptor')
#
# During handling of the above exception, another exception occurred:
#
#     return do()
#            ^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 903, in <lambda>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1253, in run
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/commlib/transports/redis.py", line 812, in run_forever
#     self._transport._rsub.ping()
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1127, in ping
#     return self._parser.can_read(timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 79, in can_read
#     return self.read_from_socket(timeout=timeout, raise_on_timeout=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     raise ConnectionError(f"Error while reading from {host_error}: {e.args}")
# redis.exceptions.ConnectionError: Error while reading from localhost:6379: (9, 'Bad file descriptor')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1253, in run
#     pubsub.get_message(ignore_subscribe_messages=True, timeout=sleep_time)
#     return self.execute_command(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 859, in execute_command
#     lambda: command(*args, **kwargs),
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 920, in try_read
#     pubsub.get_message(ignore_subscribe_messages=True, timeout=sleep_time)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1115, in get_message
#     response = self.parse_response(block=(timeout is None), timeout=timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 926, in parse_response
#     pubsub.get_message(ignore_subscribe_messages=True, timeout=sleep_time)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1115, in get_message
#     response = self.parse_response(block=(timeout is None), timeout=timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 926, in parse_response
#     self._execute(connection, connection.send_command, *args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 902, in _execute
#     return conn.retry.call_with_retry(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 62, in call_with_retry
#     lambda: command(*args, **kwargs),
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 920, in try_read
#     if not conn.can_read(timeout=timeout):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 594, in can_read
#     raise ConnectionError(f"Error while reading from {host_error}: {e.args}")
# redis.exceptions.ConnectionError: Error while reading from localhost:6379: (9, 'Bad file descriptor')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1253, in run
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 110, in read_from_socket
#     sock.settimeout(self._socket_timeout)
# OSError: [Errno 9] Bad file descriptor
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 62, in call_with_retry
#     return do()
#            ^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 903, in <lambda>
#     lambda: command(*args, **kwargs),
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 920, in try_read
#     if not conn.can_read(timeout=timeout):
#     if not conn.can_read(timeout=timeout):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 594, in can_read
#     return do()
#            ^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 903, in <lambda>
#     raise ConnectionError(f"Error while reading from {host_error}: {e.args}")
# redis.exceptions.ConnectionError: Error while reading from localhost:6379: (9, 'Bad file descriptor')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1253, in run
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1115, in get_message
#     response = self._execute(conn, try_read)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 902, in _execute
#     return self.execute_command(*args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 859, in execute_command
#     self._execute(connection, connection.send_command, *args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 902, in _execute
#     return conn.retry.call_with_retry(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 65, in call_with_retry
#     fail(error)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 904, in <lambda>
#     response = self._execute(conn, try_read)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 902, in _execute
#     return conn.retry.call_with_retry(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 65, in call_with_retry
#     fail(error)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 904, in <lambda>
#     lambda: command(*args, **kwargs),
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 594, in can_read
#     raise ConnectionError(f"Error while reading from {host_error}: {e.args}")
# redis.exceptions.ConnectionError: Error while reading from localhost:6379: (9, 'Bad file descriptor')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1253, in run
#     return conn.retry.call_with_retry(
#     response = self.parse_response(block=(timeout is None), timeout=timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 926, in parse_response
#     response = self._execute(conn, try_read)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 902, in _execute
#     return conn.retry.call_with_retry(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 65, in call_with_retry
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 577, in send_command
#     self.send_packed_command(
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 547, in send_packed_command
#     self.connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 390, in connect
#     self.on_connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 492, in on_connect
#     self.read_response()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 613, in read_response
#     fail(error)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 904, in <lambda>
#     lambda error: self._disconnect_raise_connect(conn, error),
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 892, in _disconnect_raise_connect
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 65, in call_with_retry
#     fail(error)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 904, in <lambda>
#     conn.connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 390, in connect
#     pubsub.get_message(ignore_subscribe_messages=True, timeout=sleep_time)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1115, in get_message
#     response = self._parser.read_response(disable_decoding=disable_decoding)
#     lambda error: self._disconnect_raise_connect(conn, error),
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 892, in _disconnect_raise_connect
#     pubsub.get_message(ignore_subscribe_messages=True, timeout=sleep_time)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1115, in get_message
#     response = self.parse_response(block=(timeout is None), timeout=timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 926, in parse_response
#     response = self._execute(conn, try_read)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 902, in _execute
#     return conn.retry.call_with_retry(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 65, in call_with_retry
#     fail(error)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 904, in <lambda>
#     lambda error: self._disconnect_raise_connect(conn, error),
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 892, in _disconnect_raise_connect
#     lambda error: self._disconnect_raise_connect(conn, error),
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 892, in _disconnect_raise_connect
#     response = self.parse_response(block=(timeout is None), timeout=timeout)
#     self.on_connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 492, in on_connect
#     self.read_response()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 613, in read_response
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 926, in parse_response
#     pubsub.get_message(ignore_subscribe_messages=True, timeout=sleep_time)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1115, in get_message
#     response = self.parse_response(block=(timeout is None), timeout=timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 926, in parse_response
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 128, in read_response
#     conn.connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 390, in connect
#     self.on_connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 499, in on_connect
#     conn.connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 390, in connect
#     self.on_connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 499, in on_connect
#     self.read_response()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 613, in read_response
#     response = self._execute(conn, try_read)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 902, in _execute
#     response = self._parser.read_response(disable_decoding=disable_decoding)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 128, in read_response
#     self.read_from_socket()
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 90, in read_from_socket
#     self.read_response()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 613, in read_response
#     return conn.retry.call_with_retry(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 65, in call_with_retry
#     fail(error)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 904, in <lambda>
#     lambda error: self._disconnect_raise_connect(conn, error),
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 892, in _disconnect_raise_connect
#     conn.connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 390, in connect
#     self.on_connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 492, in on_connect
#     self.read_response()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 613, in read_response
#     response = self._parser.read_response(disable_decoding=disable_decoding)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 128, in read_response
#     response = self._execute(conn, try_read)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     response = self._parser.read_response(disable_decoding=disable_decoding)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 128, in read_response
#     self.read_from_socket()
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 90, in read_from_socket
#     raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
# redis.exceptions.ConnectionError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     lambda error: self._disconnect_raise_connect(conn, error),
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 892, in _disconnect_raise_connect
#     raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
# redis.exceptions.ConnectionError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 902, in _execute
#     conn.connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 390, in connect
#     response = self._parser.read_response(disable_decoding=disable_decoding)
#     conn.connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 390, in connect
#     return conn.retry.call_with_retry(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/retry.py", line 65, in call_with_retry
# CRITICAL : stream_simulator.world : World: Actors cleaned
#     self.run()
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1257, in run
#     self.run()
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1257, in run
#     fail(error)
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 904, in <lambda>
#     self.on_connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 492, in on_connect
#     self.exception_handler(e, pubsub, self)
#   File "/usr/local/lib/python3.11/dist-packages/commlib/transports/redis.py", line 274, in exception_handler
# CRITICAL : stream_simulator.world : World: Cleaning devices
# CRITICAL : stream_simulator.world : World: Cleaning device upper_temperature
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 128, in read_response
#     self.read_from_socket()
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 90, in read_from_socket
#     raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
# redis.exceptions.ConnectionError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.on_connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 492, in on_connect
#     self.read_response()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 613, in read_response
#     response = self._parser.read_response(disable_decoding=disable_decoding)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 128, in read_response
#     self.read_from_socket()
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 91, in read_from_socket
#     self._reader.feed(self._buffer, 0, bufflen)
#     ^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'feed'
#     lambda error: self._disconnect_raise_connect(conn, error),
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 892, in _disconnect_raise_connect
#     conn.connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 390, in connect
#     self.on_connect()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 499, in on_connect
#     self.read_response()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 613, in read_response
#     response = self._parser.read_response(disable_decoding=disable_decoding)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 128, in read_response
#     self.read_from_socket()
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 90, in read_from_socket
#     raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
# redis.exceptions.ConnectionError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1257, in run
#     self.read_from_socket()
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 90, in read_from_socket
#     self.exception_handler(e, pubsub, self)
#   File "/usr/local/lib/python3.11/dist-packages/commlib/transports/redis.py", line 274, in exception_handler
#     thread.join(timeout=self._redis_pubsub_join_timeout)
#   File "/usr/lib/python3.11/threading.py", line 1116, in join
#     self.run()
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1257, in run
#     self.exception_handler(e, pubsub, self)
#   File "/usr/local/lib/python3.11/dist-packages/commlib/transports/redis.py", line 274, in exception_handler
#     thread.join(timeout=self._redis_pubsub_join_timeout)
#   File "/usr/lib/python3.11/threading.py", line 1116, in join
#     raise RuntimeError("cannot join current thread")
# RuntimeError: cannot join current thread
#     self.read_response()
#   File "/usr/local/lib/python3.11/dist-packages/redis/connection.py", line 613, in read_response
#     response = self._parser.read_response(disable_decoding=disable_decoding)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 128, in read_response
#     self.read_from_socket()
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 90, in read_from_socket
#     raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
# redis.exceptions.ConnectionError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     raise ConnectionError(SERVER_CLOSED_CONNECTION_ERROR)
# redis.exceptions.ConnectionError: Connection closed by server.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1257, in run
#     thread.join(timeout=self._redis_pubsub_join_timeout)
#   File "/usr/lib/python3.11/threading.py", line 1116, in join
#     raise RuntimeError("cannot join current thread")
# RuntimeError: cannot join current thread
#     raise RuntimeError("cannot join current thread")
# RuntimeError: cannot join current thread
#     self.exception_handler(e, pubsub, self)
#   File "/usr/local/lib/python3.11/dist-packages/commlib/transports/redis.py", line 274, in exception_handler
#     self.run()
#   File "/usr/local/lib/python3.11/dist-packages/redis/client.py", line 1257, in run
#     thread.join(timeout=self._redis_pubsub_join_timeout)
#     self.read_from_socket()
#   File "/usr/local/lib/python3.11/dist-packages/redis/_parsers/hiredis.py", line 91, in read_from_socket
#   File "/usr/lib/python3.11/threading.py", line 1116, in join
#     self._reader.feed(self._buffer, 0, bufflen)
#     ^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'feed'
#     self.exception_handler(e, pubsub, self)
#   File "/usr/local/lib/python3.11/dist-packages/commlib/transports/redis.py", line 274, in exception_handler
#     thread.join(timeout=self._redis_pubsub_join_timeout)
#   File "/usr/lib/python3.11/threading.py", line 1116, in join
#     raise RuntimeError("cannot join current thread")
# RuntimeError: cannot join current thread
#     self.exception_handler(e, pubsub, self)
#   File "/usr/local/lib/python3.11/dist-packages/commlib/transports/redis.py", line 274, in exception_handler
#     thread.join(timeout=self._redis_pubsub_join_timeout)
#   File "/usr/lib/python3.11/threading.py", line 1116, in join
#     raise RuntimeError("cannot join current thread")
# RuntimeError: cannot join current thread
#     raise RuntimeError("cannot join current thread")
# RuntimeError: cannot join current thread
# CRITICAL : stream_simulator.world : World: Device upper_temperature cleaned
# CRITICAL : stream_simulator.world : World: Cleaning device bedroom_temperature
# CRITICAL : stream_simulator.world : World: Device bedroom_temperature cleaned
# CRITICAL : stream_simulator.world : World: Cleaning device bathroom_humidity
# CRITICAL : stream_simulator.world : World: Device bathroom_humidity cleaned
# CRITICAL : stream_simulator.world : World: Cleaning device ef_thermostat_40
# CRITICAL : stream_simulator.world : World: Device ef_thermostat_40 cleaned
# CRITICAL : stream_simulator.world : World: Cleaning device ef_humidifier_41
# CRITICAL : stream_simulator.world : World: Device ef_humidifier_41 cleaned
# CRITICAL : stream_simulator.world : World: Devices cleaned
# CRITICAL : stream_simulator.simulator : World stopped

# %% [markdown]
# # Kill All

# %%
# !bash -c '[ -f streamsim.pid ] && pid=$(cat streamsim.pid) && kill $pid'
# !bash -c '[ -f appexecutor.pid ] && pid=$(cat appexecutor.pid) && kill $pid'
# !bash -c '[ -f goalexecutor.pid ] && pid=$(cat goalexecutor.pid) && kill $pid'
